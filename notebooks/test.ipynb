# %%
import pandas as pd
import os

os.getcwd()
pd.set_option('display.max_columns', None)

# %%
df_tfd = pd.read_csv(
    r'C:\Users\menge\Desktop\ml_fol\Predictive_Maintenance\artifact\11_04_2025_14_29_05\data_transformation\transformed_data\train.csv') 
# remove delimiter='' — default is comma
#df = pd.read_csv('./artifact/10_23_2025_14_15_53/data_ingestion/feature_store/RUL.csv', delimiter='')

# %%
df_tfd[20:25]
# Out:
#     unit_number  time_in_cycles subset  split  ops_1_zn  ops_2_zn  ops_3_zn  \
# 20          1.0             6.0  FD001  train -1.961827 -0.349246  0.000000
# 21          1.0             6.0  FD002  train  0.068222  0.156262 -2.391253
# 22          1.0             6.0  FD003  train  0.512295 -1.717670  0.000000
# 23          1.0             6.0  FD004  train  0.744198  0.864661  0.418779
# 24          1.0             7.0  FD001  train  0.461237  0.333203  0.000000
#
#     sensor_1_zn  sensor_2_zn  sensor_3_zn  sensor_4_zn  sensor_5_zn  \
# 20     0.000000    -1.161743    -0.987273    -1.173675    -0.999976
# 21    -0.392964    -1.143821    -1.449706    -1.315627    -0.271729
# 22     0.000000    -0.416530    -0.585746    -0.456475    -0.999980
# 23    -0.886734    -0.660105    -0.612490    -0.711532    -0.704310
# 24     0.000000    -0.401824     0.293074    -1.240337    -0.999976
#
#     sensor_6_zn  sensor_7_zn  sensor_8_zn  sensor_9_zn  sensor_10_zn  \
# ...

# %%
df_v = pd.read_csv(r'C:/Users/menge/Desktop/ml_fol/Predictive_Maintenance/artifact/11_04_2025_12_51_31/data_validation/valid_data/train.csv')
df_v.head(3)
# Out:
#    unit_number  time_in_cycles   ops_1   ops_2  ops_3  sensor_1  sensor_2  \
# 0          1.0             1.0 -0.0007 -0.0004  100.0    518.67    641.82
# 1          1.0             2.0  0.0019 -0.0003  100.0    518.67    642.15
# 2          1.0             3.0 -0.0043  0.0003  100.0    518.67    642.35
#
#    sensor_3  sensor_4  sensor_5  sensor_6  sensor_7  sensor_8  sensor_9  \
# 0   1589.70   1400.60     14.62     21.61    554.36   2388.06   9046.19
# 1   1591.82   1403.14     14.62     21.61    553.75   2388.04   9044.07
# 2   1587.99   1404.20     14.62     21.61    554.26   2388.08   9052.94
#
#    sensor_10  sensor_11  sensor_12  sensor_13  sensor_14  sensor_15  \
# 0        1.3      47.47     521.66    2388.02    8138.62     8.4195
# 1        1.3      47.49     522.28    2388.07    8131.49     8.4318
# 2        1.3      47.27     522.42    2388.03    8133.23     8.4178
#
#    sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  sensor_21 subset  \
# ...

# %%
df_v.tail(3)
# Out:
#         unit_number  time_in_cycles    ops_1  ops_2  ops_3  sensor_1  \
# 160356        249.0           253.0   0.0029   0.00  100.0    518.67
# 160357        249.0           254.0  35.0046   0.84  100.0    449.44
# 160358        249.0           255.0  42.0030   0.84  100.0    445.00
#
#         sensor_2  sensor_3  sensor_4  sensor_5  sensor_6  sensor_7  sensor_8  \
# 160356    643.68   1607.72   1430.56     14.62     21.57    569.04   2388.51
# 160357    555.77   1381.29   1148.18      5.48      7.96    199.93   2223.78
# 160358    549.85   1369.75   1147.45      3.91      5.69    142.47   2212.52
#
#         sensor_9  sensor_10  sensor_11  sensor_12  sensor_13  sensor_14  \
# 160356   9126.53       1.31      48.24     535.41    2388.48    8193.94
# 160357   8403.64       1.05      42.53     187.92    2388.83    8125.64
# 160358   8391.31       1.05      42.60     134.32    2388.66    8144.33
#
#         sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
df_ingested = pd.read_csv(r'C:/Users/menge/Desktop/ml_fol/Predictive_Maintenance/artifact/11_04_2025_12_51_31/data_ingestion/ingested/train.csv')
df_ingested.head(3)
# Out:
#    unit_number  time_in_cycles   ops_1   ops_2  ops_3  sensor_1  sensor_2  \
# 0          1.0             1.0 -0.0007 -0.0004  100.0    518.67    641.82
# 1          1.0             2.0  0.0019 -0.0003  100.0    518.67    642.15
# 2          1.0             3.0 -0.0043  0.0003  100.0    518.67    642.35
#
#    sensor_3  sensor_4  sensor_5  sensor_6  sensor_7  sensor_8  sensor_9  \
# 0   1589.70   1400.60     14.62     21.61    554.36   2388.06   9046.19
# 1   1591.82   1403.14     14.62     21.61    553.75   2388.04   9044.07
# 2   1587.99   1404.20     14.62     21.61    554.26   2388.08   9052.94
#
#    sensor_10  sensor_11  sensor_12  sensor_13  sensor_14  sensor_15  \
# 0        1.3      47.47     521.66    2388.02    8138.62     8.4195
# 1        1.3      47.49     522.28    2388.07    8131.49     8.4318
# 2        1.3      47.27     522.42    2388.03    8133.23     8.4178
#
#    sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  sensor_21 subset  \
# ...

# %%
df_original = pd.read_csv(r'C:/Users/menge/Desktop/ml_fol/Predictive_Maintenance/Prediction_Dataset/train/train.csv')

# %%
df_original.head(3)
# Out:
#    unit_number  time_in_cycles   ops_1   ops_2  ops_3  sensor_1  sensor_2  \
# 0            1               1 -0.0007 -0.0004  100.0    518.67    641.82
# 1            1               2  0.0019 -0.0003  100.0    518.67    642.15
# 2            1               3 -0.0043  0.0003  100.0    518.67    642.35
#
#    sensor_3  sensor_4  sensor_5  ...  sensor_14  sensor_15  sensor_16  \
# 0   1589.70   1400.60     14.62  ...    8138.62     8.4195       0.03
# 1   1591.82   1403.14     14.62  ...    8131.49     8.4318       0.03
# 2   1587.99   1404.20     14.62  ...    8133.23     8.4178       0.03
#
#    sensor_17  sensor_18  sensor_19  sensor_20  sensor_21  subset  split
# 0        392       2388      100.0      39.06    23.4190   FD001  train
# 1        392       2388      100.0      39.00    23.4236   FD001  train
# 2        390       2388      100.0      38.95    23.3442   FD001  train
#
# [3 rows x 28 columns]

# %%
df_test_transformed = pd.read_csv(r'C:\Users\menge\Desktop\ml_fol\Predictive_Maintenance\artifact\11_04_2025_14_29_05\data_transformation\transformed_data\test.csv')

# %%
df_test_transformed[20:25]
# Out:
#     unit_number  time_in_cycles subset split  ops_1_zn  ops_2_zn  ops_3_zn  \
# 20          1.0             6.0  FD001  test  0.552673  1.015652  0.000000
# 21          1.0             6.0  FD002  test  0.067957  0.156584 -2.391253
# 22          1.0             6.0  FD003  test -1.539179  0.322848  0.000000
# 23          1.0             6.0  FD004  test  0.067735  0.157556 -2.387853
# 24          1.0             7.0  FD001  test  0.004055  0.674428  0.000000
#
#     sensor_1_zn  sensor_2_zn  sensor_3_zn  sensor_4_zn  sensor_5_zn  \
# 20     0.000000    -1.141745    -1.859866    -1.533650    -0.999976
# 21    -0.392964    -1.154548    -1.520307    -1.327128    -0.271729
# 22     0.000000    -1.372496    -0.764883    -0.760368    -0.999980
# 23    -0.391213    -1.152036    -1.530755    -1.325556    -0.270952
# 24     0.000000    -1.141745    -1.171578    -0.454834    -0.999976
#
#     sensor_6_zn  sensor_7_zn  sensor_8_zn  sensor_9_zn  sensor_10_zn  \
# ...
