# %%
import pandas as pd
import os

os.getcwd()
pd.set_option('display.max_columns', None)

# %%
results_df = pd.read_csv(r'C:\Users\menge\Desktop\ml_fol\Predictive_Maintenance\prediction_output\predictions.csv')

results_df.head
# Out:
#    unit_number  time_in_cycles subset split  Predictions
# 0           52             271  FD003  test   250.327586
# 1           73             167  FD001  test   250.327586
# 2           53             280  FD003  test   250.327586
# 3            5             218  FD001  test   250.327586
# 4           97             283  FD002  test   279.900000

# %%
results_df.shape
# Out:
# (10, 5)
